# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Configuration

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms

# 1) Transformations
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.ToTensor()
])

# 2) Dataset
dataset = MNISTPNG("images/", "trainLabels.csv", transform=transform)

# 3) DataLoader
train_loader = DataLoader(dataset, batch_size=64, shuffle=True)

import torch
import torch.nn as nn

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        
        # Bloc 1
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Bloc 2
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # FC
        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)  

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        
        x = x.view(x.size(0), -1)  # flatten
        x = self.relu3(self.fc1(x))
        x = self.fc2(x)
        return x

#
model = SimpleCNN()

# %%
learning_rate=0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)


n_steps=5

for epoch in range(n_steps):
    for X_batch, y_batch in train_loader:
        y_pred = model(X_batch)
        loss = criterion(y_pred,y_batch)
        

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        print(f'')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 n_steps=5
#       3 for epoch in range(n_steps):
# ----> 4     for X_batch, y_batch in train_loader:
#       5         y_pred = model(X_batch)
#       6         loss = criterion(y_pred,y_batch)
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[11], line 18, in MNISTPNG.__getitem__(self, idx)
#      16 def __getitem__(self, idx):
#      17     img_name = self.labels_df.iloc[idx, 0]  # nom du fichier image
# ---> 18     label = int(self.labels_df.iloc[idx, 1])  # label
#      20     img_path = os.path.join(self.images_folder, img_name)
#      21     img = Image.open(img_path).convert("L")  # en niveau de gris
#
# ValueError: invalid literal for int() with base 10: 'deer'
